# %%
options(stringsAsFactors = FALSE, warn = -1,
        repr.plot.res = 200,
        repr.plot.width=8, repr.plot.height=4.5)

## install devtools if not installed
if(!("devtools" %in% rownames(installed.packages()))){
  install.packages("devtools",  repos = c(CRAN = "http://cran.rstudio.com"))
  }

## install bmetenrichr if not installed
if(!("bmetenrichr" %in% rownames(installed.packages()))){
   devtools::install_github(repo = "martijnmolenaar/bmetenrichr")
}

# %%
library(bmetenrichr)

# %% [markdown]
# ## simple anlayses using LION

# %%
## load example data 
data("Rappez_et_al")

# %%
## example sc_matrix
## is SpaceM dataset from Rappez et al. (2022) Nat. Methods.

Rappez_et_al$sc_matrix[1:10,1:10]
# Out:
#                 8          15        18         25         27
# C10H10N4O.K     0.01145815 0.0000000 0.00000000 0.00000000 0.00000000
# C10H10O6.K      0.00000000 0.0000000 0.00000000 0.00000000 0.00000000
# C10H11N4O7P.Na  0.00000000 0.0000000 0.00000000 0.00000000 0.00000000
# C10H11N5O3.H    0.00000000 0.0000000 0.00000000 0.00000000 0.00000000
# C10H12ClN5O3.K  0.00000000 0.0000000 0.00000000 0.00000000 0.00000000
# C10H12ClN5O3.Na 0.00000000 0.0000000 0.00000000 0.00000000 0.00000000
# C10H12ClNO4.H   0.01707534 0.0620677 0.05203464 0.01376432 0.02417577
# C10H12ClNO4.K   0.00000000 0.0000000 0.00000000 0.00000000 0.00000000
# C10H12ClNO4.Na  0.17496077 0.1702377 0.17311070 0.16992632 0.01635700
# C10H12FN5O4.H   0.00000000 0.0000000 0.00000000 0.00000000 0.00000000
#                 29          35          38         41          47
# C10H10N4O.K     0.008558847 0.000000000 0.00000000 0.000000000 0.000000000
# C10H10O6.K      0.000000000 0.000000000 0.00000000 0.000000000 0.006726224
# C10H11N4O7P.Na  0.000000000 0.005782876 0.02968958 0.000000000 0.000000000
# C10H11N5O3.H    0.000000000 0.000000000 0.00000000 0.000000000 0.000000000
# C10H12ClN5O3.K  0.000000000 0.000000000 0.00000000 0.000000000 0.000000000
# C10H12ClN5O3.Na 0.000000000 0.000000000 0.00000000 0.000000000 0.000000000
# C10H12ClNO4.H   0.028755533 0.030977567 0.03611660 0.009692678 0.031959898
# C10H12ClNO4.K   0.000000000 0.000000000 0.00000000 0.000000000 0.000000000
# C10H12ClNO4.Na  0.174631645 0.147417684 0.12427280 0.160955912 0.120047020
# C10H12FN5O4.H   0.000000000 0.000000000 0.00000000 0.000000000 0.000000000

# %%
## example annotations
rownames(Rappez_et_al$sc_matrix)[1:10]
# Out:
#  [1] "C10H10N4O.K"     "C10H10O6.K"      "C10H11N4O7P.Na"  "C10H11N5O3.H"
#  [5] "C10H12ClN5O3.K"  "C10H12ClN5O3.Na" "C10H12ClNO4.H"   "C10H12ClNO4.K"
#  [9] "C10H12ClNO4.Na"  "C10H12FN5O4.H"

# %%
## conditions in example
Rappez_et_al$conditions[1:10]
# Out:
#  [1] "F" "F" "F" "F" "F" "F" "F" "F" "F" "F"

# %%
## should the annotations be included in the analysis? 
Rappez_et_al$cellular[1:10]
# Out:
#     C10H10N4O.K      C10H10O6.K  C10H11N4O7P.Na    C10H11N5O3.H  C10H12ClN5O3.K
#           FALSE           FALSE           FALSE            TRUE           FALSE
# C10H12ClN5O3.Na   C10H12ClNO4.H   C10H12ClNO4.K  C10H12ClNO4.Na   C10H12FN5O4.H
#           FALSE           FALSE           FALSE           FALSE           FALSE

# %%
## create object

myTestRun <-
  initEnrichment(scmatrix = Rappez_et_al$sc_matrix,
                 annotations = rownames(Rappez_et_al$sc_matrix),
                 conditions = Rappez_et_al$conditions,
                 include = Rappez_et_al$cellular,
                 condition.x = "U",
                 condition.y = "F"                    )
# Out:
# Parsing isomers...
# single-cell metabolomics matrix of 3385 metabolites and 8807 cells
# active pathway: LION
#
# conditions: F, FI, FIT, U
#
# condition.x: U
# condition.y: F

# %%
## rank metabolites, in this case by t.test statistic

myTestRun <- rankScore(myTestRun, ranking.by = 't.test')
# Out:
# number of ties: 19 (1.73%)

# %%
## perform enrichment analysis with n = 100 bootstraps

myTestRun <- calcEnrichment(myTestRun, n = 100)
# Out:
# Bootstrapping...
#
# Match to pathway...
# 35.52% of annotations were matched to pathway
# Perform enrichment analysis...

# %%
## plot enrichment analysis, with enrichment score (ES) on x-axis

plotEnrichment(myTestRun, min.annotations = 5, q.value.cutoff = .05, by.statistic = "ES")
# Out:
# plot without title

# %%
## plot enrichment analysis, now with q.values on x-axis, and with LION IDs

plotEnrichment(myTestRun, min.annotations = 5, q.value.cutoff = .05, plotIDs = T, by.statistic = "q.value")
# Out:
# plot without title

# %%
## export enrichment table

enrichmentTable(myTestRun)
# Out:
#    LION_ID      LION_name                                                 n
# 1  LION:0000002 glycerolipids [GL]                                         28.0
# 2  LION:0000003 glycerophospholipids [GP]                                 292.0
# 3  LION:0000004 sphingolipids [SP]                                         49.0
# 4  LION:0000010 glycerophosphocholines [GP01]                              54.0
# 5  LION:0000011 glycerophosphoethanolamines [GP02]                         69.0
# 6  LION:0000012 glycerophosphoinositols [GP06]                             50.0
# 7  LION:0000013 glycerophosphoserines [GP03]                               48.5
# 8  LION:0000019 glycerophosphates [GP10]                                   44.0
# 9  LION:0000030 diacylglycerophosphocholines [GP0101]                      38.0
# 10 LION:0000032 1-(1z-alkenyl),2-acylglycerophosphocholines [GP0103]        5.0
# 11 LION:0000038 diacylglycerophosphoethanolamines [GP0201]                 48.0
# 12 LION:0000039 1-alkyl,2-acylglycerophosphoethanolamines [GP0202]          4.0
# 13 LION:0000040 1-(1z-alkenyl),2-acylglycerophosphoethanolamines [GP0203]   5.0
# 14 LION:0000053 diacylglycerophosphoserines [GP0301]                       40.0
# 15 LION:0000055 1-(1z-alkenyl),2-acylglycerophosphoserines [GP0303]         4.0
# 16 LION:0000063 monoacylglycerophosphoglycerols [GP0405]                    3.0
# 17 LION:0000077 ceramides [SP02]                                            8.0
# 18 LION:0000078 phosphosphingolipids [SP03]                                30.0
# 19 LION:0000080 neutral glycosphingolipids [SP05]                          11.0
# 20 LION:0000084 ceramide phosphocholines (sphingomyelins) [SP0301]         24.0
# 21 LION:0000100 fatty acid with 18 carbons or less                        208.0
# 22 LION:0000453 simple glc series [SP0501]                                 11.0
# 23 LION:0000604 triradylglycerols [GL03]                                    9.0
# 24 LION:0000607 diacylglycerols [GL0201]                                    7.0
# 25 LION:0000622 triacylglycerols [GL0301]                                   8.0
# 26 LION:0002945 fatty acid with more than 18 carbons                      185.5
# 27 LION:0002955 fatty acid with 16 carbons                                 44.0
# 28 LION:0002957 fatty acid with 18 carbons                                119.0
# 29 LION:0002959 fatty acid with 20 carbons                                 87.0
# 30 LION:0002961 fatty acid with 22 carbons                                 57.0
# 31 LION:0002962 fatty acid with 23 carbons                                  3.0
# 32 LION:0002963 fatty acid with 24 carbons                                 19.0
# 33 LION:0002966 fatty acid with less than 2 double bonds                  223.0
# 34 LION:0002967 polyunsaturated fatty acid                                151.0
# 35 LION:0002968 saturated fatty acid                                      122.0
# 36 LION:0002969 monounsaturated fatty acid                                126.5
# 37 LION:0002970 fatty acid with 2 double bonds                             52.0
# 38 LION:0002971 fatty acid with 3 double bonds                             49.5
# 39 LION:0002972 fatty acid with 4 double bonds                             29.0
# 40 LION:0002976 fatty acid with more than 3 double bonds                  109.0
# 41 LION:0002977 fatty acid with 3-5 double bonds                           97.0
# 42 LION:0012441 N-acylsphingosines (ceramides) [SP0201]                     4.0
#    ES_median  ES_sd        p.value_median p.value_sd   q.value_median
# 1   0.4463952 0.0000000000 3.787071e-05   0.000000e+00 6.740987e-04
# 2  -0.1903366 0.0038459537 3.792082e-07   2.439526e-07 1.157570e-05
# 3  -0.3102381 0.0089229080 2.908494e-04   2.107992e-04 3.162987e-03
# 4  -0.1851049 0.0261057009 5.994455e-02   7.115748e-02 1.923416e-01
# 5  -0.2145721 0.0161575127 5.674835e-03   8.151203e-03 3.421782e-02
# 6  -0.1737786 0.0001447348 1.119827e-01   1.199917e-03 2.737354e-01
# 7  -0.2061049 0.0098500855 3.747630e-02   1.581753e-02 1.450170e-01
# 8  -0.1528808 0.0011969308 2.769892e-01   1.660167e-02 4.930408e-01
# 9  -0.2246190 0.0379642153 5.349642e-02   7.806787e-02 1.785002e-01
# 10  0.4597806 0.2432954470 2.710548e-01   2.396512e-01 4.853331e-01
# 11 -0.1972185 0.0174589975 5.403861e-02   3.903887e-02 1.872756e-01
# 12 -0.4700504 0.1816587680 2.485354e-01   2.575309e-01 4.581180e-01
# 13 -0.5394798 0.1444658295 1.484931e-01   2.256629e-01 3.235986e-01
# 14 -0.1937618 0.0060726968 1.106817e-01   2.404153e-02 2.752907e-01
# 15 -0.4813940 0.2069556957 2.359561e-01   1.906605e-01 4.445549e-01
# 16 -0.5150961 0.0336726076 1.733163e-01   9.055806e-02 3.784472e-01
# 17  0.3412844 0.0494819929 2.496616e-01   1.123643e-01 4.629142e-01
# 18 -0.3992509 0.0000000000 1.823436e-04   0.000000e+00 2.318368e-03
# 19 -0.4368989 0.0274107882 3.129927e-02   7.346691e-03 1.126774e-01
# 20 -0.4316684 0.0287071526 2.513278e-04   1.217924e-03 3.213406e-03
# 21 -0.1469388 0.0095258268 1.363973e-03   2.008012e-03 1.151855e-02
# 22 -0.4368989 0.0274107882 3.129927e-02   7.346691e-03 1.126774e-01
# 23  0.8622590 0.0197195720 4.596620e-08   3.937017e-06 4.090992e-06
# 24  0.4321068 0.0187819258 1.071170e-01   1.213847e-02 2.723868e-01
# 25  0.8614679 0.0000000000 3.317287e-07   0.000000e+00 1.167576e-05
# 26 -0.1459608 0.0135914352 2.852103e-03   6.543861e-03 2.180342e-02
# 27 -0.1519802 0.0507180269 2.813855e-01   2.608693e-01 4.954111e-01
# 28 -0.1442167 0.0202472339 2.434886e-02   3.719443e-02 1.122323e-01
# 29 -0.1566515 0.0246078330 4.014135e-02   7.224450e-02 1.451740e-01
# 30 -0.1543304 0.0432216967 1.387873e-01   1.889758e-01 3.061881e-01
# 31 -0.5984469 0.1662297942 1.282834e-01   1.954709e-01 2.900957e-01
# 32 -0.2580293 0.0954616847 1.708158e-01   2.812657e-01 3.501346e-01
# 33 -0.1399655 0.0100507830 1.872482e-03   3.859302e-03 1.520221e-02
# 34 -0.1680424 0.0113018992 1.270558e-03   2.838759e-03 1.096513e-02
# 35 -0.1375125 0.0238058560 3.467435e-02   9.916769e-02 1.367776e-01
# 36 -0.1360571 0.0177088999 3.155189e-02   4.839995e-02 1.259770e-01
# 37 -0.1719612 0.0454301051 9.815083e-02   1.762145e-01 2.530728e-01
# 38 -0.1810345 0.0252353039 8.851208e-02   1.243069e-01 2.434789e-01
# 39 -0.2099083 0.0610075624 1.716867e-01   1.755272e-01 3.765681e-01
# 40 -0.1740948 0.0135891405 5.716305e-03   9.293841e-03 3.819649e-02
# 41 -0.1745775 0.0151176097 8.411372e-03   1.440765e-02 4.921606e-02
# 42  0.5909506 0.0000000000 7.600218e-02   0.000000e+00 2.170911e-01
#    q.value_sd
# 1  2.899848e-05
# 2  7.604881e-06
# 3  1.916145e-03
# 4  1.234316e-01
# 5  3.279221e-02
# 6  1.876017e-02
# 7  3.946275e-02
# 8  3.605796e-02
# 9  1.291319e-01
# 10 2.559759e-01
# 11 7.566354e-02
# 12 2.488339e-01
# 13 2.474438e-01
# 14 3.737936e-02
# 15 1.995961e-01
# 16 1.104980e-01
# 17 1.215411e-01
# 18 2.573094e-04
# 19 2.675601e-02
# 20 7.894251e-03
# 21 1.276292e-02
# 22 2.675601e-02
# 23 1.172572e-04
# 24 2.995482e-02
# 25 3.046158e-06
# 26 2.984278e-02
# 27 2.458156e-01
# 28 8.206670e-02
# 29 1.297035e-01
# 30 2.127010e-01
# 31 2.180963e-01
# 32 2.911290e-01
# 33 2.036994e-02
# 34 1.810307e-02
# 35 1.579038e-01
# 36 9.581506e-02
# 37 2.165100e-01
# 38 1.528565e-01
# 39 1.841378e-01
# 40 3.656093e-02
# 41 4.928198e-02
# 42 1.640010e-02

# %%
## now, let's test FIT vs F

myTestRun <-  setConditions(object = myTestRun, condition.x = 'F', condition.y = 'FIT')
myTestRun
# Out:
# single-cell metabolomics matrix of 3385 metabolites and 8807 cells
# active pathway: LION
#
# conditions: F, FI, FIT, U
#
# condition.x: F
# condition.y: FIT

# %%
## rank metabolites, in this case by t.test statistic

myTestRun <- rankScore(myTestRun, ranking.by = 't.test')
# Out:
# number of ties: 24 (2.19%)

# %%
myTestRun <- calcEnrichment(myTestRun, n = 100)
# Out:
# Bootstrapping...
#
# Match to pathway...
# 34.52% of annotations were matched to pathway
# Perform enrichment analysis...

# %%
plotEnrichment(myTestRun, min.annotations = 5, q.value.cutoff = .05)
# Out:
# plot without title

# %% [markdown]
# ## run LION enrichment with including isobars

# %%
## it's possible to expand the analysis by including isobars (by default, only isomers are included)
## isobars are predicted under the hood, no specific data is required
## except:
##  - for polarization_mode ('positive' or 'negative')
##  - mass_range_ppm

## create object

myTestRun <-
  initEnrichment(scmatrix = Rappez_et_al$sc_matrix, 
                 isobars = TRUE,                      ## to include isobars (default is FALSE)
                 mass_range_ppm = 3,                  ## mass range to define isobars
                 polarization_mode = "positive",      ## mode, is important to include the right adducts
                 annotations = rownames(Rappez_et_al$sc_matrix), 
                 conditions = Rappez_et_al$conditions,
                 include = Rappez_et_al$cellular,
                 condition.x = "U",
                 condition.y = "F"                    )
# Out:
# polarization_mode is: positive
# Parsing isomers...
# Parsing potential isobars...
#
# single-cell metabolomics matrix of 3385 metabolites and 8807 cells
# active pathway: LION
#
# conditions: F, FI, FIT, U
#
# condition.x: U
# condition.y: F

# %%
## rank metabolites, in this case by t.test statistic

myTestRun <- rankScore(myTestRun, ranking.by = 't.test')
# Out:
# number of ties: 19 (1.73%)

# %%
## perform enrichment analysis with n = 100 bootstraps

myTestRun <- calcEnrichment(myTestRun, n = 100)
# Out:
# Bootstrapping...
#
# Match to pathway...
# 35.34% of annotations were matched to pathway
# Perform enrichment analysis...

# %%
## example of the annotations, that now also include isobars

myTestRun$annotations[sample(which(sapply(myTestRun$isobars_list, length) > 1), size = 1)]
# Out:
# [[1]]
#               isomer              isobar1              isobar2
#           "PS(54:5)" "PI(18:1(11E)/30:0)" "PI(20:1(11Z)/28:0)"
#              isobar3              isobar4              isobar5
# "PI(18:1(11Z)/30:0)" "PI(22:1(13Z)/26:0)" "PI(24:1(15Z)/24:0)"
#              isobar6              isobar7              isobar8
# "PI(26:1(17Z)/22:0)"  "PI(18:1(6Z)/30:0)"  "PI(18:1(9Z)/30:0)"
#              isobar9             isobar10             isobar11
# "PI(22:0/26:1(17Z))" "PI(26:0/22:1(13Z))" "PI(28:0/20:1(11Z))"
#             isobar12             isobar13             isobar14
# "PI(24:0/24:1(15Z))" "PI(30:0/18:1(11E))" "PI(30:0/18:1(11Z))"
#             isobar15             isobar16             isobar17
#  "PI(30:0/18:1(6Z))"  "PI(30:0/18:1(9Z))"           "PS(52:2)"

# %%
## plot enrichment analysis, with q.values on x-axis, and with LION IDs

plotEnrichment(myTestRun, min.annotations = 5, q.value.cutoff = .05, plotIDs = T, by.statistic = "q.value")
# Out:
# plot without title

# %% [markdown]
# ## custom analyses

# %%
## it's possible to use a custom metabolite set enrichment pathway
## this should be formatted as a names list, with each element a vector of the metabolites within the set

myPathway <- myTestRun$pathway_list[sample(100, size = 20)]

str(myPathway)
# Out:
# List of 20
#  $ LION:0000602: chr [1:272] "MG(0:0/10:0/0:0)" "MG(0:0/12:0/0:0)" "MG(0:0/13:0/0:0)" "MG(0:0/14:0/0:0)" ...
#  $ LION:0000040: chr [1:1594] "PE(14:0/P-16:0)" "PE(14:0/P-18:0)" "PE(14:0/P-18:1(11Z))" "PE(14:0/P-18:1(9Z))" ...
#  $ LION:0000607: chr [1:9693] "DG(10:0/0:0/10:0)" "DG(10:0/0:0/12:0)" "DG(10:0/0:0/13:0)" "DG(10:0/0:0/14:0)" ...
#  $ LION:0000948: chr [1:3] "(10E,12Z)-(9S)-9-Hydroperoxyoctadeca-10,12-dienoic acid" "(5Z,9E,14Z)-(8xi,11R,12S)-11,12-epoxy-8-hydroxyicosa-5,9,14-trienoic Acid" "(5Z)-(15S)-11alpha-Hydroxy-9,15-dioxoprostanoate"
#  $ LION:0000076: chr [1:3] "(10E,12Z)-(9S)-9-Hydroperoxyoctadeca-10,12-dienoic acid" "(5Z,9E,14Z)-(8xi,11R,12S)-11,12-epoxy-8-hydroxyicosa-5,9,14-trienoic Acid" "(5Z)-(15S)-11alpha-Hydroxy-9,15-dioxoprostanoate"
#  $ LION:0000569: chr [1:3] "(10E,12Z)-(9S)-9-Hydroperoxyoctadeca-10,12-dienoic acid" "(5Z,9E,14Z)-(8xi,11R,12S)-11,12-epoxy-8-hydroxyicosa-5,9,14-trienoic Acid" "(5Z)-(15S)-11alpha-Hydroxy-9,15-dioxoprostanoate"
#  $ LION:0000452: chr [1:3] "(10E,12Z)-(9S)-9-Hydroperoxyoctadeca-10,12-dienoic acid" "(5Z,9E,14Z)-(8xi,11R,12S)-11,12-epoxy-8-hydroxyicosa-5,9,14-trienoic Acid" "(5Z)-(15S)-11alpha-Hydroxy-9,15-dioxoprostanoate"
#  $ LION:0000566: chr [1:3] "(10E,12Z)-(9S)-9-Hydroperoxyoctadeca-10,12-dienoic acid" "(5Z,9E,14Z)-(8xi,11R,12S)-11,12-epoxy-8-hydroxyicosa-5,9,14-trienoic Acid" "(5Z)-(15S)-11alpha-Hydroxy-9,15-dioxoprostanoate"
#  $ LION:0000072: chr [1:275] "LysoPA(0:0/16:0)" "LysoPA(0:0/18:0)" "LysoPA(0:0/18:1(9Z))" "LysoPA(0:0/18:2(9Z,12Z))" ...
#  $ LION:0000078: chr [1:2626] "SM(d16:1/24:1(15Z))" "SM(d17:1/24:0)" "SM(d17:1/24:1(15Z))" "SM(d18:0/12:0)" ...
#  $ LION:0000036: chr [1:22] "LysoPC(P-16:0)" "LysoPC(P-18:0)" "LysoPC(P-18:1(9Z))" "PC(P-14:0/0:0)" ...
#  $ LION:0000610: chr [1:3] "(10E,12Z)-(9S)-9-Hydroperoxyoctadeca-10,12-dienoic acid" "(5Z,9E,14Z)-(8xi,11R,12S)-11,12-epoxy-8-hydroxyicosa-5,9,14-trienoic Acid" "(5Z)-(15S)-11alpha-Hydroxy-9,15-dioxoprostanoate"
#  $ LION:0000575: chr [1:3] "(10E,12Z)-(9S)-9-Hydroperoxyoctadeca-10,12-dienoic acid" "(5Z,9E,14Z)-(8xi,11R,12S)-11,12-epoxy-8-hydroxyicosa-5,9,14-trienoic Acid" "(5Z)-(15S)-11alpha-Hydroxy-9,15-dioxoprostanoate"
#  $ LION:0000453: chr [1:1710] "(10E,12Z)-(9S)-9-Hydroperoxyoctadeca-10,12-dienoic acid" "(5Z,9E,14Z)-(8xi,11R,12S)-11,12-epoxy-8-hydroxyicosa-5,9,14-trienoic Acid" "(5Z)-(15S)-11alpha-Hydroxy-9,15-dioxoprostanoate" "(9Z)-(7S,8S)-Dihydroxyoctadecenoic acid" ...
#  $ LION:0000081: chr [1:5717] "(10E,12Z)-(9S)-9-Hydroperoxyoctadeca-10,12-dienoic acid" "(5Z,9E,14Z)-(8xi,11R,12S)-11,12-epoxy-8-hydroxyicosa-5,9,14-trienoic Acid" "(5Z)-(15S)-11alpha-Hydroxy-9,15-dioxoprostanoate" "Fuc-GD1b (d18:0/10:0)" ...
#  $ LION:0000041: chr [1:3] "(10E,12Z)-(9S)-9-Hydroperoxyoctadeca-10,12-dienoic acid" "(5Z,9E,14Z)-(8xi,11R,12S)-11,12-epoxy-8-hydroxyicosa-5,9,14-trienoic Acid" "(5Z)-(15S)-11alpha-Hydroxy-9,15-dioxoprostanoate"
#  $ LION:0000604: chr [1:189451] "(10E,12Z)-(9S)-9-Hydroperoxyoctadeca-10,12-dienoic acid" "(5Z,9E,14Z)-(8xi,11R,12S)-11,12-epoxy-8-hydroxyicosa-5,9,14-trienoic Acid" "(5Z)-(15S)-11alpha-Hydroxy-9,15-dioxoprostanoate" "TG(10:0/10:0/10:0)" ...
#  $ LION:0000014: chr [1:10832] "(10E,12Z)-(9S)-9-Hydroperoxyoctadeca-10,12-dienoic acid" "(5Z,9E,14Z)-(8xi,11R,12S)-11,12-epoxy-8-hydroxyicosa-5,9,14-trienoic Acid" "(5Z)-(15S)-11alpha-Hydroxy-9,15-dioxoprostanoate" "PG(16:0/16:0)" ...
#  $ LION:0000006: chr [1:9] "(10E,12Z)-(9S)-9-Hydroperoxyoctadeca-10,12-dienoic acid" "(5Z,9E,14Z)-(8xi,11R,12S)-11,12-epoxy-8-hydroxyicosa-5,9,14-trienoic Acid" "(5Z)-(15S)-11alpha-Hydroxy-9,15-dioxoprostanoate" "(9Z)-(7S,8S)-Dihydroxyoctadecenoic acid" ...
#  $ all         : chr [1:610019] "(10E,12Z)-(9S)-9-Hydroperoxyoctadeca-10,12-dienoic acid" "(5Z,9E,14Z)-(8xi,11R,12S)-11,12-epoxy-8-hydroxyicosa-5,9,14-trienoic Acid" "(5Z)-(15S)-11alpha-Hydroxy-9,15-dioxoprostanoate" "10-heptadecenoate (17:1n7)" ...

# %%
## also, custom annotations can be provided as list
my_annotations <- myTestRun$annotations
str(my_annotations[825:829])
# Out:
# List of 5
#  $ : chr [1:3] "PI(4:0/4:0)" "PI(2:0/6:0)" "PI(6:0/2:0)"
#  $ : chr(0)
#  $ : chr(0)
#  $ : chr [1:10] "PC(6:0/3:0)" "PC(3:0/6:0)" "PE(6:0/6:0)" "PE(2:0/10:0)" ...
#  $ : chr [1:10] "PC(6:0/3:0)" "PC(3:0/6:0)" "PE(6:0/6:0)" "PE(2:0/10:0)" ...

# %%
## create object

myTestRun <-
  initEnrichment(scmatrix = Rappez_et_al$sc_matrix, 
                 pathway = myPathway, 
                 termsOfInterest = "all",   ## to include 'all' terms
                 annotations = my_annotations,
                 conditions = Rappez_et_al$conditions,
                 include = Rappez_et_al$cellular, 
                 condition.x = "U",
                 condition.y = "F"                    )
# Out:
# single-cell metabolomics matrix of 3385 metabolites and 8807 cells
# active pathway: custom
#
# conditions: F, FI, FIT, U
#
# condition.x: U
# condition.y: F

# %%
## rank metabolites, in this case by t.test statistic

myTestRun <- rankScore(myTestRun, ranking.by = 't.test')
# Out:
# number of ties: 19 (1.73%)

# %%
myTestRun <- calcEnrichment(myTestRun, n = 20)
# Out:
# Bootstrapping...
#
# Match to pathway...
# 35.34% of annotations were matched to pathway
# Perform enrichment analysis...

# %%
plotEnrichment(myTestRun, min.annotations = 5, q.value.cutoff = .05)
# Out:
# plot without title

# %%
## export enrichment table

enrichmentTable(myTestRun)
# Out:
#   LION_ID      LION_name    n    ES_median  ES_sd      p.value_median
# 1 LION:0000014 LION:0000014 26.0 -0.1839402 0.01771363 3.349721e-01
# 2 LION:0000040 LION:0000040  5.5 -0.4821060 0.10393645 1.741615e-01
# 3 LION:0000078 LION:0000078 30.0 -0.3992509 0.00000000 1.823436e-04
# 4 LION:0000453 LION:0000453 11.0 -0.4368989 0.02746604 3.129927e-02
# 5 LION:0000604 LION:0000604  9.0  0.8622590 0.02238899 4.596620e-08
# 6 LION:0000607 LION:0000607  7.0  0.4321068 0.02132441 1.071170e-01
#   p.value_sd   q.value_median q.value_sd
# 1 8.529077e-02 3.715967e-01   9.282184e-02
# 2 1.731991e-01 2.307687e-01   1.787810e-01
# 3 0.000000e+00 6.078120e-04   2.974392e-05
# 4 7.361500e-03 6.994367e-02   1.796241e-02
# 5 4.469967e-06 4.596620e-07   2.781067e-05
# 6 1.378165e-02 1.606756e-01   2.040139e-02
